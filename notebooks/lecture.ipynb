# %% [markdown]
# # Initiation to research - Big Data
#
# Fanilo Andrianasolo - Date @Conference

# %% [markdown]
# # M. Fanilo ANDRIANASOLO
#
# * Business Center Analytics @Worldline Lyon
# * Analytics architect, sharing on Big Data / Data Science
#
#
# * <i class="fa fa-envelope"></i>   andfanilo@gmail.com
# * <i class="fa fa-twitter"></i>   @andfanilo

# %% [markdown]
# Data is everywhere

# %% [markdown]
# _IoT, sensors, social media, explosion of data producers. Quote some statistics here for how much new machines are being produced, or new data sources, or APIs_

# %% [markdown]
# Data is complex

# %% [markdown]
# _show som raw log to deal with, images to analyze, ECGs..._

# %% [markdown]
# Data is huge

# %% [markdown]
# _stats for volume generated by Linkedin or Facebook for example_

# %% [markdown]
# Data is fast

# %% [markdown]
# _Boeing generated data by its turbine stat is good_

# %% [markdown]
# ...but data is beautiful

# %% [markdown]
# _hum_

# %% [markdown]
# ...but data is valuable

# %% [markdown]
# _hum, use cases where we saved lives ? predicting Hurricane Sandy_

# %% [markdown]
# ...but data is everywhere

# %% [markdown]
# _Data analytics in every domain uses kind of the same tools, so can reproduce everywhere. Cross domain example to find, maybe image segmentation in retail, telecom, healthcare.. _

# %% [markdown]
# So

# %% [markdown]
# <table class="table">
#   <thead>
#     <tr>
#       <th scope="col">#</th>
#       <th scope="col">First Name</th>
#       <th scope="col">Last Name</th>
#       <th scope="col">Username</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th scope="row">1</th>
#       <td>Mark</td>
#       <td>Otto</td>
#       <td>@mdo</td>
#     </tr>
#     <tr>
#       <th scope="row">2</th>
#       <td>Jacob</td>
#       <td>Thornton</td>
#       <td>@fat</td>
#     </tr>
#     <tr>
#       <th scope="row">3</th>
#       <td>Larry</td>
#       <td>the Bird</td>
#       <td>@twitter</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2>Vertical Slides</h2>
# 						<p>Slides can be nested inside of each other.</p>
# 						<p>Use the <em>Space</em> key to navigate through all slides.</p>
# 						<br>
# 						<a href="#" class="navigate-down">
# 							<img width="178" height="238" data-src="https://s3.amazonaws.com/hakim-static/reveal-js/arrow.png" alt="Down arrow">
# 						</a>

# %% [markdown]
#   <div class="item-1">1</div>
#   <div class="item-2">2</div>
#   <div class="item-3">3</div>
#   <div class="item-4">4</div>
#   <div class="item-5">5</div>
#   <div class="item-6">6</div>
#   <div class="item-7">7</div>
#   <div class="item-8">8</div>
#   <div class="item-9">This is where I want you little nine :D !</div>

# %% [markdown]
# As the future generation, you have the ability to make a change.

# %% [markdown]
# _Call to adventure !_

# %% [markdown]
# But even that looks hard to you..

# %% [markdown]
# _Refusal of the call begins. Tell why it's hard, find examples_

# %% [markdown]
# You need to work with data processing libraries that you can use in dev and in production

# %% [markdown]
# You need to collaborate with experts

# %% [markdown]
# You need to explain that work to executives

# %% [markdown]
# > As a data scientist, how can I share reproducible data analysis ?
#
# > As a data scientist, how can I run distributed data analysis on huge datasets ?

# %% [markdown]
# Here are some magical tools to aid you

# %% [markdown]
# _meeting with the mentor_

# %% [markdown]
# # Python environments

# %% [markdown]
# # Jupyter notebook

# %%
# Hi, I'm a Python cell !
1 + 2
# Out:
# 3

# %% [markdown]
# and I am a Markdown page

# %% [markdown]
# # Apache Spark

# %% [markdown]
# # Conclusion
